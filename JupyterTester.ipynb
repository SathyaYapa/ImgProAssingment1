# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv


im = cv.imread(r"D:\Saves\Python\ImgPro\images\PXL.jpg", cv.IMREAD_ANYCOLOR)
assert im is not None

hist= cv.calcHist([im],[2], None, [256], [0,256])

plt.plot(hist)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

imbgr = cv.imread(r"D:\Saves\Python\ImgProAssingment1\images\spider.png", cv.IMREAD_ANYCOLOR)
imrgb= cv.cvtColor(imbgr, cv.COLOR_BGR2RGB)


#Q2(a)
imhsv = cv.cvtColor(imbgr, cv.COLOR_BGR2HSV)
h,s,v = cv.split(imhsv)

#Q2(b,c)
a=15000
def trnsf(x):
    return( min( ((x)+(a*(np.exp(-(x-128)**2/(2*a**2))))/128), 255) )

t = np.arange(0,256).astype(np.uint8)
for p in range(0,256):
    t[p]=trnsf(t[p])

for i in range(s.shape[0]):
    for j in range(s.shape[1]):
        s[i,j]=trnsf(s[i,j])
        
#Q2(d)
imhsv2=cv.merge([h, s, v])
imrgb2= cv.cvtColor(imhsv2, cv.COLOR_HSV2RGB)

#Q2(e)
print(s.shape)
fig, ax= plt.subplots(1,2, figsize=(10,20))
ax[0].imshow(imrgb)
ax[0].set_title('Original')
ax[1].imshow(imrgb2)
ax[1].set_title('Vibrancy-Enhanced')
plt.show()

plt.plot(t)
plt.title("Intensity Transformation")
# Out:
# (438, 780)
# Text(0.5, 1.0, 'Intensity Transformation')

# %% [markdown]
# Q3

# %%
 


import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

imbgr = cv.imread(r"D:\Saves\Python\ImgProAssingment1\images\highlights_and_shadows.jpg", cv.IMREAD_ANYCOLOR)
imrgb = cv.cvtColor(imbgr, cv.COLOR_BGR2RGB)

imlab = cv.cvtColor(imbgr, cv.COLOR_BGR2LAB)
l,a,b = cv.split(imlab)
l2,a,b = cv.split(imlab)

gamma = 1.4                                            #value of gamma
t = np.array([(i/255.)**gamma*255 for i in range(256)], dtype=np.uint8)

l = cv.LUT(l,t)

imlab2 =cv.merge([l, a, b]) 
imrgb2 = cv.cvtColor(imlab2, cv.COLOR_LAB2RGB)        #Gamma Correction Applied

hist1 = cv.calcHist([l],[0], None, [256], [0,256])
hist2 = cv.calcHist([l2],[0], None, [256], [0,256])

fig, ax = plt.subplots(1,2, figsize=(20,40))
ax[0].imshow(imrgb)
ax[0].set_title('Original')
ax[1].imshow(imrgb2)
ax[1].set_title('Corrected')

fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[0].plot(hist2)
ax[0].set_title('Original')
ax[1].plot(hist1)
ax[1].set_title('Corrected')
plt.show()



print(hist1[2,0])
# Out:
# 24995.0

# %% [markdown]
# Q4

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im= cv.imread(r"D:\Saves\Python\ImgProAssingment1\images\washed_out_aerial_image.png", cv.IMREAD_GRAYSCALE)

hist= cv.calcHist([im],[0], None, [256], [0,256])
cdf= hist.cumsum()
cdf_normalized= cdf*(256)/(cdf.max())

eq_im= cdf_normalized[im]    
eq_hist= cv.calcHist([eq_im],[0], None, [256], [0,256]) 

fig, ax = plt.subplots(1,2, figsize=(15,20))
ax[0].imshow(im, cmap='gray')
ax[0].set_title('Original Image')
ax[1].imshow(eq_im, cmap='gray')
ax[1].set_title('Histogram Equalized')

fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[0].plot(hist)
ax[0].set_title('Histogram of the Original Image')
ax[1].plot(eq_hist)
ax[1].set_title('Histogram of the Equalized Image')
plt.show()
